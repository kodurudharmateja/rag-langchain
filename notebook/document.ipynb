# %% [markdown]
# ### DATA INGESTION

# %%
### DOC STRUCTURE
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="This is sample main text",
    metadata={"source": "sample.txt", "author": "John Doe", "date": "2023-01-01"}
)
print(doc)
# Out:
# page_content='This is sample main text' metadata={'source': 'sample.txt', 'author': 'John Doe', 'date': '2023-01-01'}
